# %%
from collections import defaultdict

from medpy.io import load
import os
import numpy as np
import torch

import random
from copy import deepcopy
from scipy.ndimage import map_coordinates, fourier_gaussian
from scipy.ndimage.filters import gaussian_filter, gaussian_gradient_magnitude
from scipy.ndimage.morphology import grey_dilation
from skimage.transform import resize
from scipy.ndimage.measurements import label as lb
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import SimpleITK as sitk
from collections import OrderedDict
import pickle
from subprocess import check_call
# from utilities.file_and_folder_operations import subfiles
def subfiles(folder,res, join=True, prefix=None, suffix=None, sort=True):
    # if join:
    #     l = os.path.join
    # else:
    #     l = lambda x, y: y
    # for i in os.listdir(folder):
    #     print(i)
    # res = [l(folder, i) for i in os.listdir(folder) if os.path.isfile(os.path.join(folder, i))
    #         and (prefix is None or i.startswith(prefix))
    #         and (suffix is None or i.endswith(suffix))]
    
    dirList=[]
    for i in os.listdir(folder):
        wholepath = os.path.join(folder, i)
        if os.path.isdir(wholepath):
            dirList.append(wholepath)
        if os.path.isfile(wholepath):
            res.append(wholepath)
            if not wholepath.endswith(suffix):
                res.remove(wholepath)
    if dirList:
        for subDir in dirList:
            subfiles(subDir,res,join=False,suffix=".nii.gz")
    if sort:
        res.sort()
    

def create_nonzero_mask(data):
    from scipy.ndimage import binary_fill_holes
    assert len(data.shape) == 4 or len(data.shape) == 3, "data must have shape (C, X, Y, Z) or shape (C, X, Y)"
    nonzero_mask = np.zeros(data.shape[1:], dtype=bool)
    # print(4,data.shape[1:]) 155*240*240
    # print(5,data.shape[0]) 4
    for c in range(data.shape[0]):
        this_mask = data[c] != 0
        nonzero_mask = nonzero_mask | this_mask
    nonzero_mask = binary_fill_holes(nonzero_mask)
    return nonzero_mask


def get_bbox_from_mask(mask, outside_value=0):
    mask_voxel_coords = np.where(mask != outside_value)
    minzidx = int(np.min(mask_voxel_coords[0]))
    maxzidx = int(np.max(mask_voxel_coords[0])) + 1
    minxidx = int(np.min(mask_voxel_coords[1]))
    maxxidx = int(np.max(mask_voxel_coords[1])) + 1
    minyidx = int(np.min(mask_voxel_coords[2]))
    maxyidx = int(np.max(mask_voxel_coords[2])) + 1
    return [[minzidx, maxzidx], [minxidx, maxxidx], [minyidx, maxyidx]]


def crop_to_bbox(image, bbox):
    assert len(image.shape) == 3, "only supports 3d images"
    resizer = (slice(bbox[0][0], bbox[0][1]), slice(bbox[1][0], bbox[1][1]), slice(bbox[2][0], bbox[2][1]))
    return image[resizer]

def crop_to_nonzero(data, seg=None, nonzero_label=-1):
    """
    :param data:
    :param seg:
    :param nonzero_label: this will be written into the segmentation map
    :return:
    """
    nonzero_mask = create_nonzero_mask(data)
    bbox = get_bbox_from_mask(nonzero_mask, 0)
    # print(9,bbox)

    cropped_data = []
    for c in range(data.shape[0]):
        # if c==0:
        #     print(7,data[0].shape)
        cropped = crop_to_bbox(data[c], bbox)
        # if c==0:
        #     print(8,cropped.shape)
        cropped_data.append(cropped[None])
    data = np.vstack(cropped_data)

    if seg is not None:
        cropped_seg = []
        for c in range(seg.shape[0]):
            
            cropped = crop_to_bbox(seg[c], bbox)
            cropped_seg.append(cropped[None])
        seg = np.vstack(cropped_seg)

    nonzero_mask = crop_to_bbox(nonzero_mask, bbox)[None]
    if seg is not None:
        seg[(seg == 0) & (nonzero_mask == 0)] = nonzero_label
    
    return data, seg, bbox

def preprocess_data(root_dir='/home/jovyan/main/BraTS2020_TrainingData/', y_shape=64, z_shape=64):
    # image_dir = os.path.join(root_dir, 'imagesTr')
    image_dir = root_dir
    label_dir = os.path.join(root_dir, 'labelsTr')
    output_dir = os.path.join(root_dir, 'preprocessed')
    classes = 4

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print('Created' + output_dir + '...')

    class_stats = defaultdict(int)
    total = 0
    nii_files=[]
    subfiles(image_dir,nii_files, suffix=".nii.gz", join=False)

    # for i in range(0, len(nii_files)):
    #     if nii_files[i].startswith("._"):
    #         nii_files[i] = nii_files[i][2:]
    # print("--------")
    seg_files=[]
    data_files=[]
    data_itk = []
    seg_itk=[]
    count=0
    for f in nii_files:
        count=count+1
        image,metadata=load(f)
        label=metadata.get_sitkimage()
        if "seg" in f:
            seg_files.append(f)
            
            seg_itk.append(label)
            
        else:
            data_itk.append(label)
            data_files.append(f)
        if count==5:
            print(seg_files,data_files)
            data_npy = np.vstack([sitk.GetArrayFromImage(d)[None] for d in data_itk])
            print(1,np.array(data_itk[0].GetSize()))
            print(2,np.array(data_itk[0].GetSize())[[2, 1, 0]])
            
            seg_npy = np.vstack([sitk.GetArrayFromImage(s)[None] for s in seg_itk])
            data_npy= data_npy.astype(np.float32)
            seg_npy= seg_npy.astype(np.float32)
            # npImage = sitk.GetArrayFromImage(label)
            # print(2,npImage)
            # z = int(label.GetSize()[2]/2)
            # plt.figure(figsize=(5,5))
            # plt.imshow(image[:,:,z], 'gray')
            # plt.show()
            properties = OrderedDict()
            properties["original_size_of_raw_data"] = np.array(data_itk[0].GetSize())[[2, 1, 0]]
            properties["original_spacing"] = np.array(data_itk[0].GetSpacing())[[2, 1, 0]]
            properties["list_of_data_files"] = data_files
            properties["seg_file"] = seg_files
            properties["itk_origin"] = data_itk[0].GetOrigin()
            properties["itk_spacing"] = data_itk[0].GetSpacing()
            properties["itk_direction"] = data_itk[0].GetDirection()
            print(4,data_npy.shape,seg_npy.shape)
            data_npy,seg_npy,bbox=crop_to_nonzero(data_npy, seg_npy, nonzero_label=-1)    
            print(5,data_npy.shape,seg_npy.shape)
            properties["crop_bbox"] = bbox
            properties['classes'] = np.unique(seg_npy)
            seg_npy[seg_npy < -1] = 0
            properties["size_after_cropping"] = data_npy[0].shape 
            print(6,properties['classes'],properties['classes'].shape)
            case_id=seg_files[0].split("/")[-1].split(".nii.gz")[0][0:-4]
            all_data = np.vstack((data_npy, seg_npy))
            np.savez_compressed(os.path.join('/home/jovyan/main/BraTS2020_TrainingData/'+case_id, "%s.npz" % case_id), data=all_data)
            with open(os.path.join('/home/jovyan/main/BraTS2020_TrainingData/'+case_id, "%s.pkl" % case_id), 'wb') as file:
                pickle.dump(properties, file)
            
            count=0
            data_files=[]
            seg_files=[]
            data_itk = []
            seg_itk=[]
        # print(os.path.join(image_dir, f))
        # image, _ = load(os.path.join(image_dir, f))
        # label, _ = load(os.path.join(label_dir, f.replace('_0000', '')))
        # print(image.shape)
        # print(1,image)
        # print(label.getSize())
    
    
preprocess_data()
# Out:
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 135, 173, 137) (1, 135, 173, 137)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 140, 187, 134) (1, 140, 187, 134)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 135, 163, 129) (1, 135, 163, 129)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 140, 182, 135) (1, 140, 182, 135)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 140, 175, 133) (1, 140, 175, 133)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 141, 177, 133) (1, 141, 177, 133)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 138, 170, 139) (1, 138, 170, 139)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 138, 179, 140) (1, 138, 179, 140)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 144, 170, 130) (1, 144, 170, 130)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 141, 171, 130) (1, 141, 171, 130)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 142, 160, 152) (1, 142, 160, 152)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 143, 178, 138) (1, 143, 178, 138)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 140, 164, 145) (1, 140, 164, 145)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 143, 179, 141) (1, 143, 179, 141)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 141, 176, 144) (1, 141, 176, 144)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 140, 176, 133) (1, 140, 176, 133)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 141, 177, 140) (1, 141, 177, 140)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 136, 167, 137) (1, 136, 167, 137)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 137, 167, 133) (1, 137, 167, 133)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 139, 180, 140) (1, 139, 180, 140)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 136, 157, 133) (1, 136, 157, 133)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 143, 187, 132) (1, 143, 187, 132)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 147, 168, 127) (1, 147, 168, 127)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 144, 170, 138) (1, 144, 170, 138)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 139, 160, 131) (1, 139, 160, 131)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 142, 184, 141) (1, 142, 184, 141)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 142, 172, 134) (1, 142, 172, 134)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 142, 179, 144) (1, 142, 179, 144)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 138, 161, 132) (1, 138, 161, 132)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 140, 182, 132) (1, 140, 182, 132)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 145, 177, 140) (1, 145, 177, 140)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 143, 172, 129) (1, 143, 172, 129)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 140, 167, 133) (1, 140, 167, 133)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 144, 162, 128) (1, 144, 162, 128)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 130, 167, 148) (1, 130, 167, 148)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 139, 158, 137) (1, 139, 158, 137)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 135, 162, 142) (1, 135, 162, 142)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 139, 172, 130) (1, 139, 172, 130)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 147, 167, 125) (1, 147, 167, 125)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 140, 187, 137) (1, 140, 187, 137)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 141, 165, 143) (1, 141, 165, 143)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 142, 165, 142) (1, 142, 165, 142)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 144, 168, 146) (1, 144, 168, 146)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 139, 173, 136) (1, 139, 173, 136)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 136, 162, 135) (1, 136, 162, 135)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4, 143, 174, 133) (1, 143, 174, 133)
# 6 [-1.  0.  1.  2.  4.] (5,)
# ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_seg.nii.gz'] ['/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_flair.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_t1.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_t1ce.nii.gz', '/home/jovyan/main/BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_t2.nii.gz']
# 1 [240 240 155]
# 2 [155 240 240]
# 4 (4, 155, 240, 240) (1, 155, 240, 240)
# 5 (4,